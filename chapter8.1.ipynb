# %%
import numpy as np

def reweight_distribution(original_distribution, temperature=0.5):
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    return distribution / np.sum(distribution)

# %%
from tensorflow import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='http://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Downloading data from http://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# 614400/600901 [==============================] - 0s 0us/step
# 말뭉치 크기: 600893

# %%
maxlen = 60
step = 3

sentences = []

next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('시퀀스 개수:', len(sentences))

chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype = np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 57
# 벡터화...

# %%
from tensorflow.keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

for epoch in range(1, 60):
    print('에포크', epoch)
    model.fit(x, y, batch_size=128, epochs=1)

    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트:"' + seed_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text

        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# 1565/1565 [==============================] - 27s 17ms/step - loss: 1.6148
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# r the same man is a constand the same the same the same the sharm of the same the stand for the same and the same the same the same the discompliness of the man is a morality of the same the same which is a comparisen and some the same the same the same which he soul, and some the far the same the same the same the same the same the same the same the surming the same the problem of the far the mor
# ------ 온도: 0.5
# r the says of the seems there and in the greement and sense of surtable of the same the more the right the moral a precaused in the amparible sense of the state of the partion of the naduence of the small the bear does and the great man is not to the are sympathy, and the compalition of the once the comparismine is relation of man, and the discover to philosophers and religion of the derest and ch
# ------ 온도: 1.0
# r as the gomes
# such oncefulation the naining basen as a religion" is other contral the se churdne) as their pencual istlomembaticiablanned familance, does improvite, it is i our bart and world and himself conceler, is
# the assept, by thing that you not things as i opirence to him the faw hardure of the seas about by the baring poyt on i
# fireness
# of have first been a hense mivon,
# and is whenoursf ar
# ------ 온도: 1.2
# r one, himself "nation a distises been eforres, he will sympathye morater
# time it re doestabely things, od stativilian age
# valuationy,
# out
# last. which thestbory as peepizen"s.--later "mogient much
# and actranbing,lenhiim., the "(agnication know they."
#
# .
#
# phors the
# samoult, them
# as tr! its that theresmiganadide: imparal--is
# an
# "fherieocy on but
# orir last
# omecmenlx"; crues: us intride if the kind ba
# 에포크 2
# 1565/1565 [==============================] - 30s 19ms/step - loss: 1.5267
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# r the seriousness, and bething the seriousness of the has the sense of the excessions of the preprise of the consideres the self-same the consequently the strung and the consequently and the consequently and the desire to the consequently the consequently and it is the seriousness, the consequently the seriousness, the will by the consequently to be had the consequently and the present and the wil
# ------ 온도: 0.5
# r the christianity,
# for the same the last to be consequently the desire to the charm of the primition of the most become in the learns his formed and of the subject of the principle of the states to our philosophy of the strendul of the cate of the man "have a value and itself--for the cause of his our one disconse to be be a prenain the really it is the conduct a something to thinker to the self-
# ------ 온도: 1.0
# or comething abseluter it
# teeps, perspected, the syn cganing than it is differenced gumatt,,who, wisk: that pxyhers: and oncal
# it is it who noce no lowically man sievers of manifuct. that is the whils
# truth away astrocress if-not to nosly persons.--the learn consideres and the romant to beg.  mughty which
# or gruites of the hughed and consans are now carce
# of his lower to prowe-standaric; how
# has t
# ------ 온도: 1.2
# r
# juable t--what had followed, cheleveved.
# "himself idsable evolurng, tourefutness,ars
# referling look,
# inventious" thir dyeptinimess, become cholation of the a vary of yes,
# lven eessons, higherritiplalimats, now the is,
# down periol at exucted libuistion that philosophy squarity, is provert
# of we are .at wrich "henter relati isws, always honory presupt,. but thinked arrited has ruod ifform di  it i
# 에포크 3
# 1565/1565 [==============================] - 31s 20ms/step - loss: 1.4821
# --- 시드 텍스트:"the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# r the deep the present and the perhaps and the standard and the self-dering of the belief in the strength and the present the more the strange and the man as the conscience of the suffering the spirit and the stringly and the present and also the stringly and the spirits of the something and the deep the stringly and something is a present one of the strength which is a conscience of the spirits a
# ------ 온도: 0.5
# r the consequence of the religious conscience of still below. it is as is a for the down the intellect of the perhaps it is a something in the barish in the most desire and present and a general possessiness of the nety that woman, who always here and all the sufficity for the fance of man, the even all conscience with the whole of the conscience is a preditions the regard of the delises in a stil
# ------ 온도: 1.0
# rled: in spirits out
# of things of jufury man, and are be
# yound, lower attain idea intelfesunt surdeverary,aulaleble with this men as to perhaps other autten the  came mean aodidies
# willmous alite goigh-even.", there is woman-lo-growtrd, are creately esvined. -he weaker painh much what desire it
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-050ba7a02d77> in <module>()
#      21                 sampled[0, t, char_indices[char]] = 1.
#      22
# ---> 23             preds = model.predict(sampled, verbose=0)[0]
#      24             next_index = sample(preds, temperature)
#      25             next_char = chars[next_index]
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1766           use_multiprocessing=use_multiprocessing,
#    1767           model=self,
# -> 1768           steps_per_execution=self._steps_per_execution)
#    1769
#    1770       # Container that configures and calls `tf.keras.Callback`s.
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1401   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1402     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1403   return DataHandler(*args, **kwargs)
#    1404
#    1405
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1163         use_multiprocessing=use_multiprocessing,
#    1164         distribution_strategy=tf.distribute.get_strategy(),
# -> 1165         model=model)
#    1166
#    1167     strategy = tf.distribute.get_strategy()
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     323       return flat_dataset
#     324
# --> 325     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     326
#     327     dataset = self.slice_inputs(indices_dataset, inputs)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in flat_map(self, map_func, name)
#    2046       Dataset: A `Dataset`.
#    2047     """
# -> 2048     return FlatMapDataset(self, map_func, name=name)
#    2049
#    2050   def interleave(self,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, name)
#    5548     self._input_dataset = input_dataset
#    5549     self._map_func = StructuredFunctionWrapper(
# -> 5550         map_func, self._transformation_name(), dataset=input_dataset)
#    5551     if not isinstance(self._map_func.output_structure, DatasetSpec):
#    5552       raise TypeError(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    4531         fn_factory = trace_tf_function(defun_kwargs)
#    4532
# -> 4533     self._function = fn_factory()
#    4534     # There is no graph to add in eager mode.
#    4535     add_to_graph &= not context.executing_eagerly()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    3243     """
#    3244     graph_function = self._get_concrete_function_garbage_collected(
# -> 3245         *args, **kwargs)
#    3246     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    3247     return graph_function
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3208       args, kwargs = None, None
#    3209     with self._lock:
# -> 3210       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3211       seen_names = set()
#    3212       captured = object_identity.ObjectIdentitySet(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3555
#    3556           self._function_cache.missed.add(call_context_key)
# -> 3557           graph_function = self._create_graph_function(args, kwargs)
#    3558           self._function_cache.primary[cache_key] = graph_function
#    3559
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3407         # places (like Keras) where the FuncGraph lives longer than the
#    3408         # ConcreteFunction.
# -> 3409         shared_func_graph=False)
#    3410     return graph_function
#    3411
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __init__(self, func_graph, attrs, shared_func_graph, function_spec)
#    1592     # FuncGraph directly.
#    1593     self._delayed_rewrite_functions = _DelayedRewriteGradientFunctions(
# -> 1594         func_graph, self._attrs, self._garbage_collector)
#    1595     self._first_order_tape_functions = {}
#    1596     self._higher_order_tape_functions = {}
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __init__(self, func_graph, attrs, func_graph_deleter)
#     683     self._inference_function = _EagerDefinedFunction(
#     684         _inference_name(self._func_graph.name), self._func_graph,
# --> 685         self._func_graph.inputs, self._func_graph.outputs, attrs)
#     686     self._attrs = attrs
#     687     self._gradient_name = None
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __init__(self, name, graph, inputs, outputs, attrs)
#     501     function_def = function_pb2.FunctionDef()
#     502     function_def.ParseFromString(compat.as_bytes(proto_data))
# --> 503     self._name = compat.as_bytes(function_def.signature.name)
#     504     with ops.init_scope():
#     505       if context.executing_eagerly():
#
# KeyboardInterrupt:
