# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
from keras import models
from keras import layers

network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape =(28*28,)))
network.add(layers.Dense(10, activation='softmax'))

# %%
network.compile(optimizer='rmsprop',
                loss = 'categorical_crossentropy',
                metrics=['accuracy'])

# %%
train_images = train_images.reshape((60000, 28*28))
train_images = train_images.astype('float32')/255

test_images = test_images.reshape((10000, 28*28))
test_images = test_images.astype('float32') / 255

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
from tensorflow.keras.utils import to_categorical

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2580 - accuracy: 0.9246
# Epoch 2/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1036 - accuracy: 0.9690
# Epoch 3/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0687 - accuracy: 0.9795
# Epoch 4/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0502 - accuracy: 0.9854
# Epoch 5/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0375 - accuracy: 0.9885

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0678 - accuracy: 0.9787

# %%
print('test_acc:', test_acc)
# Out:
# test_acc: 0.9786999821662903
