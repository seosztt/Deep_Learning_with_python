# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32)]              0
#
#  dense (Dense)               (None, 32768)             1081344
#
#  leaky_re_lu (LeakyReLU)     (None, 32768)             0
#
#  reshape (Reshape)           (None, 16, 16, 128)       0
#
#  conv2d (Conv2D)             (None, 16, 16, 256)       819456
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 16, 16, 256)       0
#
#  conv2d_transpose (Conv2DTra  (None, 32, 32, 256)      1048832
#  nspose)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 32, 32, 256)       0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 256)       1638656
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 32, 32, 256)       0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 256)       1638656
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 32, 32, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 3)         37635
#
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

x = layers.Dropout(0.4)(x)

x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_4 (Conv2D)           (None, 30, 30, 128)       3584
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 30, 30, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 128)       262272
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 14, 14, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 6, 6, 128)         262272
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 6, 6, 128)         0
#
#  conv2d_7 (Conv2D)           (None, 2, 2, 128)         262272
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 2, 2, 128)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
import os
from tensorflow.keras.preprocessing import image

(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

x_train = x_train[y_train.flatten() == 6]

x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
save_dir = '/content/drive/MyDrive/Colab Notebooks/datasets/'
if not os.path.exists(save_dir):
    os.mkdir(save_dir)

start = 0
for step in range(iterations):
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    generated_images = generator.predict(random_latent_vectors)

    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])

    labels += 0.05 * np.random.random(labels.shape)

    d_loss = discriminator.train_on_batch(combined_images, labels)

    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    misleading_targets = np.zeros((batch_size, 1))

    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
      start = 0

    if step % 100 == 0:
        gan.save_weights('gan.h5')

        print('스텝 %s에서 판별자 손실: %s' % (step, d_loss))
        print('스텝 %s에서 적대적 손실: %s' % (step, a_loss))

        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# 스텝 0에서 판별자 손실: 0.6804543733596802
# 스텝 0에서 적대적 손실: 0.6497493386268616
# 스텝 100에서 판별자 손실: 0.6890763640403748
# 스텝 100에서 적대적 손실: 0.7577543258666992
# 스텝 200에서 판별자 손실: 0.6992138624191284
# 스텝 200에서 적대적 손실: 0.8921961784362793
# 스텝 300에서 판별자 손실: 0.6915251016616821
# 스텝 300에서 적대적 손실: 0.7002824544906616
# 스텝 400에서 판별자 손실: 0.7016614675521851
# 스텝 400에서 적대적 손실: 0.7443892359733582
# 스텝 500에서 판별자 손실: 0.6940037608146667
# 스텝 500에서 적대적 손실: 0.7626518607139587
# 스텝 600에서 판별자 손실: 1.0899631977081299
# 스텝 600에서 적대적 손실: 0.8179904818534851
# 스텝 700에서 판별자 손실: 0.6889094114303589
# 스텝 700에서 적대적 손실: 0.7578237056732178
# 스텝 800에서 판별자 손실: 0.7049548029899597
# 스텝 800에서 적대적 손실: 0.7931138277053833
# 스텝 900에서 판별자 손실: 0.6858012080192566
# 스텝 900에서 적대적 손실: 0.7123100161552429
# 스텝 1000에서 판별자 손실: 0.6869970560073853
# 스텝 1000에서 적대적 손실: 0.7463937997817993
# 스텝 1100에서 판별자 손실: 0.7240415811538696
# 스텝 1100에서 적대적 손실: 0.7489287853240967
# 스텝 1200에서 판별자 손실: 0.678460419178009
# 스텝 1200에서 적대적 손실: 0.7042055726051331
# 스텝 1300에서 판별자 손실: 0.7048912048339844
# 스텝 1300에서 적대적 손실: 0.7482205629348755
# 스텝 1400에서 판별자 손실: 0.7063448429107666
# 스텝 1400에서 적대적 손실: 0.7423469424247742
# 스텝 1500에서 판별자 손실: 0.6919184327125549
# 스텝 1500에서 적대적 손실: 0.7726138830184937
# 스텝 1600에서 판별자 손실: 0.6914955377578735
# 스텝 1600에서 적대적 손실: 0.7862988710403442
# 스텝 1700에서 판별자 손실: 0.7017489671707153
# 스텝 1700에서 적대적 손실: 0.7428765892982483
# 스텝 1800에서 판별자 손실: 0.7049657106399536
# 스텝 1800에서 적대적 손실: 0.7668077945709229
# 스텝 1900에서 판별자 손실: 0.6889348030090332
# 스텝 1900에서 적대적 손실: 0.6618019938468933
# 스텝 2000에서 판별자 손실: 0.6847251653671265
# 스텝 2000에서 적대적 손실: 0.7339258790016174
# 스텝 2100에서 판별자 손실: 0.7101941704750061
# 스텝 2100에서 적대적 손실: 0.8232986330986023
# 스텝 2200에서 판별자 손실: 0.7130223512649536
# 스텝 2200에서 적대적 손실: 0.7738927006721497
# 스텝 2300에서 판별자 손실: 0.6737693548202515
# 스텝 2300에서 적대적 손실: 0.9196794629096985
# 스텝 2400에서 판별자 손실: 0.6825580596923828
# 스텝 2400에서 적대적 손실: 0.73600172996521
# 스텝 2500에서 판별자 손실: 0.7109500169754028
# 스텝 2500에서 적대적 손실: 0.7530948519706726
# 스텝 2600에서 판별자 손실: 0.7001794576644897
# 스텝 2600에서 적대적 손실: 0.738127589225769
# 스텝 2700에서 판별자 손실: 0.6876546144485474
# 스텝 2700에서 적대적 손실: 0.7871032357215881
# 스텝 2800에서 판별자 손실: 0.6749765872955322
# 스텝 2800에서 적대적 손실: 0.8209202885627747
# 스텝 2900에서 판별자 손실: 0.6879771947860718
# 스텝 2900에서 적대적 손실: 0.7298732995986938
# 스텝 3000에서 판별자 손실: 0.7267540693283081
# 스텝 3000에서 적대적 손실: 0.7197188138961792
# 스텝 3100에서 판별자 손실: 0.6950093507766724
# 스텝 3100에서 적대적 손실: 0.775504469871521
# 스텝 3200에서 판별자 손실: 0.6862196326255798
# 스텝 3200에서 적대적 손실: 0.6959661245346069
# 스텝 3300에서 판별자 손실: 0.7444698214530945
# 스텝 3300에서 적대적 손실: 0.7501571774482727
# 스텝 3400에서 판별자 손실: 0.7153804302215576
# 스텝 3400에서 적대적 손실: 0.7333952188491821
# 스텝 3500에서 판별자 손실: 0.7115616202354431
# 스텝 3500에서 적대적 손실: 0.7417548298835754
# 스텝 3600에서 판별자 손실: 0.69427090883255
# 스텝 3600에서 적대적 손실: 0.7362661957740784
# 스텝 3700에서 판별자 손실: 0.6970839500427246
# 스텝 3700에서 적대적 손실: 0.7523216009140015
# 스텝 3800에서 판별자 손실: 0.9189578890800476
# 스텝 3800에서 적대적 손실: 0.7154514789581299
# 스텝 3900에서 판별자 손실: 0.6985796093940735
# 스텝 3900에서 적대적 손실: 0.7395804524421692
# 스텝 4000에서 판별자 손실: 0.6950618028640747
# 스텝 4000에서 적대적 손실: 0.7704955339431763
# 스텝 4100에서 판별자 손실: 0.6888381838798523
# 스텝 4100에서 적대적 손실: 0.8079591989517212
# 스텝 4200에서 판별자 손실: 0.687177836894989
# 스텝 4200에서 적대적 손실: 0.757492184638977
# 스텝 4300에서 판별자 손실: 0.6958449482917786
# 스텝 4300에서 적대적 손실: 0.7635778784751892
# 스텝 4400에서 판별자 손실: 0.709578812122345
# 스텝 4400에서 적대적 손실: 0.9532096982002258
# 스텝 4500에서 판별자 손실: 0.6861163377761841
# 스텝 4500에서 적대적 손실: 0.7758440971374512
# 스텝 4600에서 판별자 손실: 0.696761965751648
# 스텝 4600에서 적대적 손실: 0.7966313362121582
# 스텝 4700에서 판별자 손실: 0.6734898686408997
# 스텝 4700에서 적대적 손실: 0.7406342625617981
# 스텝 4800에서 판별자 손실: 0.6955546140670776
# 스텝 4800에서 적대적 손실: 0.6183006167411804
# 스텝 4900에서 판별자 손실: 0.6851914525032043
# 스텝 4900에서 적대적 손실: 0.7524663209915161
# 스텝 5000에서 판별자 손실: 0.6975811123847961
# 스텝 5000에서 적대적 손실: 0.7881910800933838
# 스텝 5100에서 판별자 손실: 0.7079117894172668
# 스텝 5100에서 적대적 손실: 0.767409086227417
# 스텝 5200에서 판별자 손실: 0.6985406875610352
# 스텝 5200에서 적대적 손실: 0.7527693510055542
# 스텝 5300에서 판별자 손실: 0.6903186440467834
# 스텝 5300에서 적대적 손실: 0.7630050182342529
# 스텝 5400에서 판별자 손실: 0.6861766576766968
# 스텝 5400에서 적대적 손실: 0.7513926029205322
# 스텝 5500에서 판별자 손실: 0.6920703053474426
# 스텝 5500에서 적대적 손실: 0.7638440132141113
# 스텝 5600에서 판별자 손실: 0.6867343783378601
# 스텝 5600에서 적대적 손실: 0.7603285312652588
# 스텝 5700에서 판별자 손실: 0.7326950430870056
# 스텝 5700에서 적대적 손실: 0.7864940762519836
# 스텝 5800에서 판별자 손실: 0.7934823632240295
# 스텝 5800에서 적대적 손실: 0.7975818514823914
# 스텝 5900에서 판별자 손실: 0.6879416704177856
# 스텝 5900에서 적대적 손실: 0.7512795329093933
# 스텝 6000에서 판별자 손실: 0.7068912386894226
# 스텝 6000에서 적대적 손실: 0.7558967471122742
# 스텝 6100에서 판별자 손실: 0.6824637651443481
# 스텝 6100에서 적대적 손실: 0.7535308599472046
# 스텝 6200에서 판별자 손실: 0.6969151496887207
# 스텝 6200에서 적대적 손실: 0.8162955045700073
# 스텝 6300에서 판별자 손실: 0.7006399035453796
# 스텝 6300에서 적대적 손실: 0.7626979351043701
# 스텝 6400에서 판별자 손실: 0.6957535743713379
# 스텝 6400에서 적대적 손실: 0.7217390537261963
# 스텝 6500에서 판별자 손실: 0.7013422250747681
# 스텝 6500에서 적대적 손실: 0.7287203669548035
# 스텝 6600에서 판별자 손실: 0.7027684450149536
# 스텝 6600에서 적대적 손실: 0.7477149963378906
# 스텝 6700에서 판별자 손실: 0.6894022226333618
# 스텝 6700에서 적대적 손실: 0.773302435874939
# 스텝 6800에서 판별자 손실: 0.6815572381019592
# 스텝 6800에서 적대적 손실: 0.7613941431045532
# 스텝 6900에서 판별자 손실: 0.6863200664520264
# 스텝 6900에서 적대적 손실: 0.7839886546134949
# 스텝 7000에서 판별자 손실: 0.7463580369949341
# 스텝 7000에서 적대적 손실: 0.8232690691947937
# 스텝 7100에서 판별자 손실: 0.7051151990890503
# 스텝 7100에서 적대적 손실: 0.7787669897079468
# 스텝 7200에서 판별자 손실: 0.6948255300521851
# 스텝 7200에서 적대적 손실: 0.8186110258102417
# 스텝 7300에서 판별자 손실: 0.7055773735046387
# 스텝 7300에서 적대적 손실: 0.8207119703292847
# 스텝 7400에서 판별자 손실: 0.6851205825805664
# 스텝 7400에서 적대적 손실: 0.8080785870552063
# 스텝 7500에서 판별자 손실: 0.6850956082344055
# 스텝 7500에서 적대적 손실: 0.7526348829269409
# 스텝 7600에서 판별자 손실: 0.7306817173957825
# 스텝 7600에서 적대적 손실: 0.8227595090866089
# 스텝 7700에서 판별자 손실: 0.7226020693778992
# 스텝 7700에서 적대적 손실: 0.8308340311050415
# 스텝 7800에서 판별자 손실: 0.6939454674720764
# 스텝 7800에서 적대적 손실: 0.8018556833267212
# 스텝 7900에서 판별자 손실: 0.6781072616577148
# 스텝 7900에서 적대적 손실: 0.7644823789596558
# 스텝 8000에서 판별자 손실: 0.680514931678772
# 스텝 8000에서 적대적 손실: 0.7842242121696472
# 스텝 8100에서 판별자 손실: 0.6692830324172974
# 스텝 8100에서 적대적 손실: 0.9469714164733887
# 스텝 8200에서 판별자 손실: 0.6712451577186584
# 스텝 8200에서 적대적 손실: 0.8175674676895142
# 스텝 8300에서 판별자 손실: 0.6810342073440552
# 스텝 8300에서 적대적 손실: 0.7649996876716614
# 스텝 8400에서 판별자 손실: 0.7577268481254578
# 스텝 8400에서 적대적 손실: 0.8290656805038452
# 스텝 8500에서 판별자 손실: 0.6738764047622681
# 스텝 8500에서 적대적 손실: 0.8828269243240356
# 스텝 8600에서 판별자 손실: 0.6940892338752747
# 스텝 8600에서 적대적 손실: 0.9329925775527954
# 스텝 8700에서 판별자 손실: 0.6779992580413818
# 스텝 8700에서 적대적 손실: 0.733284592628479
# 스텝 8800에서 판별자 손실: 0.6796808242797852
# 스텝 8800에서 적대적 손실: 0.8278065919876099
# 스텝 8900에서 판별자 손실: 0.6992350816726685
# 스텝 8900에서 적대적 손실: 0.6626459956169128
# 스텝 9000에서 판별자 손실: 1.4314720630645752
# 스텝 9000에서 적대적 손실: 8.980926513671875
# 스텝 9100에서 판별자 손실: 0.6729941368103027
# 스텝 9100에서 적대적 손실: 0.7788282632827759
# 스텝 9200에서 판별자 손실: 0.6786648035049438
# 스텝 9200에서 적대적 손실: 0.7955986261367798
# 스텝 9300에서 판별자 손실: 0.7244552373886108
# 스텝 9300에서 적대적 손실: 1.1176822185516357
# 스텝 9400에서 판별자 손실: 0.6946576833724976
# 스텝 9400에서 적대적 손실: 0.7747169733047485
# 스텝 9500에서 판별자 손실: 0.6645520925521851
# 스텝 9500에서 적대적 손실: 0.7888849973678589
# 스텝 9600에서 판별자 손실: 0.6688690185546875
# 스텝 9600에서 적대적 손실: 0.8405641317367554
# 스텝 9700에서 판별자 손실: 0.8264538049697876
# 스텝 9700에서 적대적 손실: 1.0774080753326416
# 스텝 9800에서 판별자 손실: 0.6516726613044739
# 스텝 9800에서 적대적 손실: 0.8443565368652344
# 스텝 9900에서 판별자 손실: 0.6660910844802856
# 스텝 9900에서 적대적 손실: 0.8210784196853638

# %%
import matplotlib.pyplot as plt
random_latent_vectors = np.random.normal(size=(10, latent_dim))

generated_images = generator.predict(random_latent_vectors)

for i in range(generated_images.shape[0]):
    img = image.array_to_img(generated_images[i] * 255., scale=False)
    plt.figure()
    plt.imshow(img)
    
plt.show()
